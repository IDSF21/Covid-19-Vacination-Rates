# %% [markdown]
# ## Import Dependencies

# %%
import sys
sys.path.append("..")

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import altair as alt

# from helpers import utils, plots
import utils
import plots

# %% [markdown]
# ## Load Dataset

# %%
covid_data = utils.get_covid_data()
covid_data
# Out:
#            Location Collection Date  Total Vaccinations  People Vaccinated  \
# 0       Afghanistan      2020-02-24                 NaN                NaN
# 1       Afghanistan      2020-02-25                 NaN                NaN
# 2       Afghanistan      2020-02-26                 NaN                NaN
# 3       Afghanistan      2020-02-27                 NaN                NaN
# 4       Afghanistan      2020-02-28                 NaN                NaN
# ...             ...             ...                 ...                ...
# 123979     Zimbabwe      2021-10-11           5594808.0          3176445.0
# 123980     Zimbabwe      2021-10-12           5612476.0          3183015.0
# 123981     Zimbabwe      2021-10-13           5632534.0          3190977.0
# 123982     Zimbabwe      2021-10-14           5654267.0          3200122.0
# 123983     Zimbabwe      2021-10-15                 NaN                NaN
#
#         People Fully Vaccinated  Population
# 0                           NaN  39835428.0
# 1                           NaN  39835428.0
# 2                           NaN  39835428.0
# 3                           NaN  39835428.0
# 4                           NaN  39835428.0
# ...                         ...         ...
# 123979                2418363.0  15092171.0
# 123980                2429461.0  15092171.0
# 123981                2441557.0  15092171.0
# 123982                2454145.0  15092171.0
# 123983                      NaN  15092171.0
#
# [123984 rows x 6 columns]

# %% [markdown]
# ### Get list of countries

# %%
countries = utils.get_country_list()
print(countries)
# Out:
# ['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola', 'Anguilla', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan', 'Bolivia', 'Bonaire Sint Eustatius and Saba', 'Bosnia and Herzegovina', 'Botswana', 'Brazil', 'British Virgin Islands', 'Brunei', 'Bulgaria', 'Burkina Faso', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde', 'Cayman Islands', 'Central African Republic', 'Chad', 'Chile', 'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands', 'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao', 'Cyprus', 'Czechia', 'Democratic Republic of Congo', 'Denmark', 'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt', 'El Salvador', 'England', 'Equatorial Guinea', 'Estonia', 'Eswatini', 'Ethiopia', 'Faeroe Islands', 'Falkland Islands', 'Fiji', 'Finland', 'France', 'French Polynesia', 'Gabon', 'Gambia', 'Georgia', 'Germany', 'Ghana', 'Gibraltar', 'Greece', 'Greenland', 'Grenada', 'Guatemala', 'Guernsey', 'Guinea', 'Guinea-Bissau', 'Guyana', 'Haiti', 'Honduras', 'Hong Kong', 'Hungary', 'Iceland', 'India', 'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Isle of Man', 'Israel', 'Italy', 'Jamaica', 'Japan', 'Jersey', 'Jordan', 'Kazakhstan', 'Kenya', 'Kiribati', 'Kosovo', 'Kuwait', 'Kyrgyzstan', 'Laos', 'Latvia', 'Lebanon', 'Lesotho', 'Liberia', 'Libya', 'Liechtenstein', 'Lithuania', 'Luxembourg', 'Macao', 'Madagascar', 'Malawi', 'Malaysia', 'Maldives', 'Mali', 'Malta', 'Mauritania', 'Mauritius', 'Mexico', 'Moldova', 'Monaco', 'Mongolia', 'Montenegro', 'Montserrat', 'Morocco', 'Mozambique', 'Myanmar', 'Namibia', 'Nauru', 'Nepal', 'Netherlands', 'New Caledonia', 'New Zealand', 'Nicaragua', 'Niger', 'Nigeria', 'Niue', 'North Macedonia', 'Northern Cyprus', 'Northern Ireland', 'Norway', 'Oman', 'Pakistan', 'Palestine', 'Panama', 'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines', 'Pitcairn', 'Poland', 'Portugal', 'Qatar', 'Romania', 'Russia', 'Rwanda', 'Saint Helena', 'Saint Kitts and Nevis', 'Saint Lucia', 'Saint Vincent and the Grenadines', 'Samoa', 'San Marino', 'Sao Tome and Principe', 'Saudi Arabia', 'Scotland', 'Senegal', 'Serbia', 'Seychelles', 'Sierra Leone', 'Singapore', 'Sint Maarten (Dutch part)', 'Slovakia', 'Slovenia', 'Solomon Islands', 'Somalia', 'South Africa', 'South Korea', 'South Sudan', 'Spain', 'Sri Lanka', 'Sudan', 'Suriname', 'Sweden', 'Switzerland', 'Syria', 'Taiwan', 'Tajikistan', 'Tanzania', 'Thailand', 'Timor', 'Togo', 'Tokelau', 'Tonga', 'Trinidad and Tobago', 'Tunisia', 'Turkey', 'Turkmenistan', 'Turks and Caicos Islands', 'Tuvalu', 'Uganda', 'Ukraine', 'United Arab Emirates', 'United Kingdom', 'United States', 'Uruguay', 'Uzbekistan', 'Vanuatu', 'Venezuela', 'Vietnam', 'Wales', 'Wallis and Futuna', 'Yemen', 'Zambia', 'Zimbabwe']

# %% [markdown]
# ## Print Complete DataFrame as HTML

# %%
utils.print_complete_dataframe(covid_data.iloc[:5])
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Location</th>
#       <th>Collection Date</th>
#       <th>Total Vaccinations</th>
#       <th>People Vaccinated</th>
#       <th>People Fully Vaccinated</th>
#       <th>Population</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Afghanistan</td>
#       <td>2020-02-24</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>39835428.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Afghanistan</td>
#       <td>2020-02-25</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>39835428.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Afghanistan</td>
#       <td>2020-02-26</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>39835428.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Afghanistan</td>
#       <td>2020-02-27</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>39835428.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Afghanistan</td>
#       <td>2020-02-28</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>39835428.0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Preprocess data
#
# Drop NaNs (Total Vaccinations, People Vaccinated, People Fully Vaccinated, Population),
#
# Drop Duplicates (Based on Location)
#
# Add Column to represent Percentage Fully Vaccinated
#
#     Percentage Fully Vaccinated = People Fully Vaccinated / Population * 100

# %%
dataset = utils.preprocess_covid_data(covid_data)
dataset
# Out:
#                  Location Collection Date  Total Vaccinations  \
# 543           Afghanistan      2021-08-20        1.201286e+06
# 1210               Africa      2021-10-15        1.710956e+08
# 1807              Albania      2021-10-13        1.816580e+06
# 2388              Algeria      2021-09-25        1.408292e+07
# 2982              Andorra      2021-09-26        1.020320e+05
# ...                   ...             ...                 ...
# 121644  Wallis and Futuna      2021-10-12        1.100900e+04
# 122277              World      2021-10-15        6.638294e+09
# 122813              Yemen      2021-09-27        3.561730e+05
# 123370             Zambia      2021-09-07        6.029960e+05
# 123982           Zimbabwe      2021-10-14        5.654267e+06
#
#         People Vaccinated  People Fully Vaccinated    Population  \
# 543          7.705420e+05             4.307440e+05  3.983543e+07
# 1210         1.048424e+08             6.883170e+07  1.373486e+09
# 1807         9.707030e+05             8.458770e+05  2.872934e+06
# 2388         6.017036e+06             4.032942e+06  4.461663e+07
# 2982         5.431200e+04             4.772000e+04  7.735400e+04
# ...                   ...                      ...           ...
# 121644       5.749000e+03             5.260000e+03  1.109400e+04
# 122277       3.735482e+09             2.823759e+09  7.874966e+09
# 122813       3.080250e+05             4.814800e+04  3.049064e+07
# 123370       3.110490e+05             2.919470e+05  1.892066e+07
# 123982       3.200122e+06             2.454145e+06  1.509217e+07
#
#         Percentage Fully Vaccinated
# 543                        1.081309
# 1210                       5.011458
# 1807                      29.442967
# 2388                       9.039101
# 2982                      61.690410
# ...                             ...
# 121644                    47.413016
# 122277                    35.857418
# 122813                     0.157911
# 123370                     1.543007
# 123982                    16.261047
#
# [225 rows x 7 columns]

# %% [markdown]
# ## Country-Continental split
#
# Split data for countries and continents into two dataframes

# %%
countries_data, continents_data = utils.country_continental_split(dataset)
countries_data.head()
# Out:
#          Location Collection Date  Total Vaccinations  People Vaccinated  \
# 543   Afghanistan      2021-08-20           1201286.0           770542.0
# 1807      Albania      2021-10-13           1816580.0           970703.0
# 2388      Algeria      2021-09-25          14082920.0          6017036.0
# 2982      Andorra      2021-09-26            102032.0            54312.0
# 3575       Angola      2021-10-14           4448653.0          3158501.0
#
#       People Fully Vaccinated  Population  Percentage Fully Vaccinated
# 543                  430744.0  39835428.0                     1.081309
# 1807                 845877.0   2872934.0                    29.442967
# 2388                4032942.0  44616626.0                     9.039101
# 2982                  47720.0     77354.0                    61.690410
# 3575                1290152.0  33933611.0                     3.801989

# %%
continents_data.head()
# Out:
#              Location Collection Date  Total Vaccinations  People Vaccinated  \
# 1210           Africa      2021-10-15        1.710956e+08       1.048424e+08
# 6494             Asia      2021-10-15        4.480253e+09       2.541010e+09
# 37831          Europe      2021-10-15        8.225248e+08       4.325363e+08
# 38463  European Union      2021-10-15        5.787278e+08       3.047014e+08
# 82449   North America      2021-10-15        6.491530e+08       3.539533e+08
#
#        People Fully Vaccinated    Population  Percentage Fully Vaccinated
# 1210              6.883170e+07  1.373486e+09                     5.011458
# 6494              1.841308e+09  4.678445e+09                    39.357259
# 37831             4.016609e+08  7.489630e+08                    53.628945
# 38463             2.865587e+08  4.471899e+08                    64.079864
# 82449             2.947244e+08  5.965813e+08                    49.402225

# %% [markdown]
# ## Total Vaccinations Administered

# %% [markdown]
# ### Top 10 countries

# %%
top_10_vaccinations_by_countries = utils.sort_and_return_top_k(countries_data)
top_10_vaccinations_by_countries.head()
# Out:
#              Location Collection Date  Total Vaccinations  People Vaccinated  \
# 23923           China      2021-09-18        2.174043e+09       1.100842e+09
# 51824           India      2021-10-15        9.711634e+08       6.934161e+08
# 118136  United States      2021-10-15        4.065709e+08       2.183181e+08
# 16383          Brazil      2021-10-15        2.544843e+08       1.555128e+08
# 57545           Japan      2021-10-14        1.782555e+08       9.459932e+07
#
#         People Fully Vaccinated    Population  Percentage Fully Vaccinated
# 23923              1.022207e+09  1.444216e+09                    70.779366
# 51824              2.777473e+08  1.393409e+09                    19.932935
# 118136             1.886552e+08  3.329151e+08                    56.667664
# 16383              1.037549e+08  2.139934e+08                    48.485072
# 57545              8.365618e+07  1.260508e+08                    66.367041

# %%
plots.plot_bars(top_10_vaccinations_by_countries, 'Total Vaccinations:Q', 'Location:O', plot_type = plots.PLOT_TYPES.FULLY_VACCINATED)
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Total Vaccinations administered per continent

# %%
total_vaccinations_by_continents = utils.sort_and_return_top_k(continents_data, sort_by=['Total Vaccinations'])
total_vaccinations_by_continents
# Out:
#               Location Collection Date  Total Vaccinations  People Vaccinated  \
# 6494              Asia      2021-10-15        4.480253e+09       2.541010e+09
# 37831           Europe      2021-10-15        8.225248e+08       4.325363e+08
# 82449    North America      2021-10-15        6.491530e+08       3.539533e+08
# 38463   European Union      2021-10-15        5.787278e+08       3.047014e+08
# 103487   South America      2021-10-15        4.743950e+08       2.799747e+08
# 1210            Africa      2021-10-15        1.710956e+08       1.048424e+08
# 84531          Oceania      2021-10-15        4.087258e+07       2.316535e+07
#
#         People Fully Vaccinated    Population  Percentage Fully Vaccinated
# 6494               1.841308e+09  4.678445e+09                    39.357259
# 37831              4.016609e+08  7.489630e+08                    53.628945
# 82449              2.947244e+08  5.965813e+08                    49.402225
# 38463              2.865587e+08  4.471899e+08                    64.079864
# 103487             1.995274e+08  4.342601e+08                    45.946517
# 1210               6.883170e+07  1.373486e+09                     5.011458
# 84531              1.770722e+07  4.321995e+07                    40.970016

# %%
plots.plot_bars(total_vaccinations_by_continents, 'Total Vaccinations:Q', 'Location:O', plot_type = plots.PLOT_TYPES.FULLY_VACCINATED)
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Fully Vaccinated Visualization

# %% [markdown]
# ### Fully Vaccinated Info for Top X Countries

# %%
full_vaccinations_by_countries = utils.sort_and_return_top_k(countries_data, sort_by=['Percentage Fully Vaccinated'])
full_vaccinations_by_countries
# Out:
#                     Location Collection Date  Total Vaccinations  \
# 44173              Gibraltar      2021-10-15             81966.0
# 89488               Pitcairn      2021-09-07                94.0
# 90680               Portugal      2021-10-11          16104710.0
# 116879  United Arab Emirates      2021-10-15          20619734.0
# 21560         Cayman Islands      2021-10-14            109919.0
# 70443                  Malta      2021-10-14            848445.0
# 51198                Iceland      2021-10-14            562426.0
# 99953              Singapore      2021-10-14           9787176.0
# 105302                 Spain      2021-10-14          70982052.0
# 91245                  Qatar      2021-09-11           4578600.0
#
#         People Vaccinated  People Fully Vaccinated  Population  \
# 44173             39970.0                  39751.0     33691.0
# 89488                47.0                     47.0        47.0
# 90680           8975593.0                8782671.0  10167923.0
# 116879          9494889.0                8505838.0   9991083.0
# 21560             55780.0                  55780.0     66498.0
# 70443            425218.0                 424538.0    514564.0
# 51198            282338.0                 277837.0    343360.0
# 99953           4730374.0                4674723.0   5896684.0
# 105302         37868453.0               37029165.0  46745211.0
# 91245           2360308.0                2218292.0   2930524.0
#
#         Percentage Fully Vaccinated
# 44173                    117.986999
# 89488                    100.000000
# 90680                     86.376254
# 116879                    85.134294
# 21560                     83.882222
# 70443                     82.504412
# 51198                     80.917113
# 99953                     79.277150
# 105302                    79.214885
# 91245                     75.696087

# %%
plots.plot_bars(full_vaccinations_by_countries, 'Percentage Fully Vaccinated:Q', 'Location:O', plot_type = plots.PLOT_TYPES.FULLY_VACCINATED)
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Fully Vaccinated Statistics by Continent

# %%
full_vaccinations_by_continents = utils.sort_and_return_top_k(continents_data, sort_by=['Percentage Fully Vaccinated'])
full_vaccinations_by_continents
# Out:
#               Location Collection Date  Total Vaccinations  People Vaccinated  \
# 38463   European Union      2021-10-15        5.787278e+08       3.047014e+08
# 37831           Europe      2021-10-15        8.225248e+08       4.325363e+08
# 82449    North America      2021-10-15        6.491530e+08       3.539533e+08
# 103487   South America      2021-10-15        4.743950e+08       2.799747e+08
# 84531          Oceania      2021-10-15        4.087258e+07       2.316535e+07
# 6494              Asia      2021-10-15        4.480253e+09       2.541010e+09
# 1210            Africa      2021-10-15        1.710956e+08       1.048424e+08
#
#         People Fully Vaccinated    Population  Percentage Fully Vaccinated
# 38463              2.865587e+08  4.471899e+08                    64.079864
# 37831              4.016609e+08  7.489630e+08                    53.628945
# 82449              2.947244e+08  5.965813e+08                    49.402225
# 103487             1.995274e+08  4.342601e+08                    45.946517
# 84531              1.770722e+07  4.321995e+07                    40.970016
# 6494               1.841308e+09  4.678445e+09                    39.357259
# 1210               6.883170e+07  1.373486e+09                     5.011458

# %%
plots.plot_bars(full_vaccinations_by_continents, 'Percentage Fully Vaccinated:Q', 'Location:O', plot_type = plots.PLOT_TYPES.FULLY_VACCINATED)
# Out:
# alt.Chart(...)

# %% [markdown]
# ## At least One Dose Visualization

# %% [markdown]
# ### At least One Dose Info for Top X Countries

# %%
people_vaccinated_by_countries = utils.sort_and_return_top_k(countries_data, sort_by=['People Vaccinated'])
people_vaccinated_by_countries
# Out:
#              Location Collection Date  Total Vaccinations  People Vaccinated  \
# 23923           China      2021-09-18        2.174043e+09       1.100842e+09
# 51824           India      2021-10-15        9.711634e+08       6.934161e+08
# 118136  United States      2021-10-15        4.065709e+08       2.183181e+08
# 16383          Brazil      2021-10-15        2.544843e+08       1.555128e+08
# 52417       Indonesia      2021-10-15        1.668617e+08       1.054647e+08
# 57545           Japan      2021-10-14        1.782555e+08       9.459932e+07
# 72608          Mexico      2021-10-14        1.105745e+08       6.795715e+07
# 85727        Pakistan      2021-10-12        9.355119e+07       6.494770e+07
# 43313         Germany      2021-10-15        1.098920e+08       5.723109e+07
# 114495         Turkey      2021-10-15        1.137095e+08       5.479955e+07
#
#         People Fully Vaccinated    Population  Percentage Fully Vaccinated
# 23923              1.022207e+09  1.444216e+09                    70.779366
# 51824              2.777473e+08  1.393409e+09                    19.932935
# 118136             1.886552e+08  3.329151e+08                    56.667664
# 16383              1.037549e+08  2.139934e+08                    48.485072
# 52417              6.139706e+07  2.763618e+08                    22.216188
# 57545              8.365618e+07  1.260508e+08                    66.367041
# 72608              5.077262e+07  1.302622e+08                    38.977242
# 85727              3.480985e+07  2.251999e+08                    15.457309
# 43313              5.465827e+07  8.390047e+07                    65.146564
# 114495             4.711910e+07  8.504274e+07                    55.406377

# %%
plots.plot_bars(people_vaccinated_by_countries, 'People Vaccinated:Q', 'Location:O', plot_type = plots.PLOT_TYPES.PEOPLE_VACCINATED)
# Out:
# alt.Chart(...)

# %%
financial_data = utils.get_financial_data()
financial_df = financial_data.copy()

# %%
financial_df.columns
# Out:
# Index(['Location', 'Population', 'Polulation Density', 'GDP per capita',
#        'Extreme Poverty', 'HDI'],
#       dtype='object')

# %%
financial_df.columns = ['Location', 'Population', 'Population Density', 'GDP', 'Extreme Poverty', 'Human Development Index']
financial_df
# Out:
#            Location  Population  Population Density       GDP  \
# 0       Afghanistan  39835428.0              54.422  1803.987
# 1       Afghanistan  39835428.0              54.422  1803.987
# 2       Afghanistan  39835428.0              54.422  1803.987
# 3       Afghanistan  39835428.0              54.422  1803.987
# 4       Afghanistan  39835428.0              54.422  1803.987
# ...             ...         ...                 ...       ...
# 123979     Zimbabwe  15092171.0              42.729  1899.775
# 123980     Zimbabwe  15092171.0              42.729  1899.775
# 123981     Zimbabwe  15092171.0              42.729  1899.775
# 123982     Zimbabwe  15092171.0              42.729  1899.775
# 123983     Zimbabwe  15092171.0              42.729  1899.775
#
#         Extreme Poverty  Human Development Index
# 0                   NaN                    0.511
# 1                   NaN                    0.511
# 2                   NaN                    0.511
# 3                   NaN                    0.511
# 4                   NaN                    0.511
# ...                 ...                      ...
# 123979             21.4                    0.571
# 123980             21.4                    0.571
# 123981             21.4                    0.571
# 123982             21.4                    0.571
# 123983             21.4                    0.571
#
# [123984 rows x 6 columns]

# %%
financial_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123984 entries, 0 to 123983
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Location                 123984 non-null  object
#  1   Population               123111 non-null  float64
#  2   Population Density       114518 non-null  float64
#  3   GDP                      109948 non-null  float64
#  4   Extreme Poverty          73606 non-null   float64
#  5   Human Development Index  109663 non-null  float64
# dtypes: float64(5), object(1)
# memory usage: 5.7+ MB

# %%
financial_df.isnull().sum()
# Out:
# Location                       0
# Population                   873
# Population Density          9466
# GDP                        14036
# Extreme Poverty            50378
# Human Development Index    14321
# dtype: int64

# %%
financial_df = financial_df.drop_duplicates(subset=['Location'], keep='last')#.drop(['Extreme Poverty', 'Human Development Index'], axis=1)
financial_df
# Out:
#                  Location    Population  Population Density        GDP  \
# 599           Afghanistan  3.983543e+07              54.422   1803.987
# 1210               Africa  1.373486e+09                 NaN        NaN
# 1809              Albania  2.872934e+06             104.871  11803.431
# 2408              Algeria  4.461663e+07              17.348  13913.839
# 3001              Andorra  7.735400e+04             163.755        NaN
# ...                   ...           ...                 ...        ...
# 121644  Wallis and Futuna  1.109400e+04                 NaN        NaN
# 122277              World  7.874966e+09              58.045  15469.207
# 122831              Yemen  3.049064e+07              53.508   1479.147
# 123408             Zambia  1.892066e+07              22.995   3689.251
# 123983           Zimbabwe  1.509217e+07              42.729   1899.775
#
#         Extreme Poverty  Human Development Index
# 599                 NaN                    0.511
# 1210                NaN                      NaN
# 1809                1.1                    0.795
# 2408                0.5                    0.748
# 3001                NaN                    0.868
# ...                 ...                      ...
# 121644              NaN                      NaN
# 122277             10.0                    0.737
# 122831             18.8                    0.470
# 123408             57.5                    0.584
# 123983             21.4                    0.571
#
# [233 rows x 6 columns]

# %%
financial_df.isnull().sum()
# Out:
# Location                     0
# Population                   2
# Population Density          25
# GDP                         38
# Extreme Poverty            107
# Human Development Index     43
# dtype: int64

# %% [markdown]
# ## Discussion
# 29 Countries do not have GDP information. These countries can not be used in the analysis of access to vaccines by GDP. Such countries would be dropped from the dataset.

# %%
countries_financial_df = financial_df[financial_df['Location'].isin(countries)]
countries_financial_df
# Out:
#                  Location  Population  Population Density        GDP  \
# 599           Afghanistan  39835428.0              54.422   1803.987
# 1809              Albania   2872934.0             104.871  11803.431
# 2408              Algeria  44616626.0              17.348  13913.839
# 3001              Andorra     77354.0             163.755        NaN
# 3576               Angola  33933611.0              23.890   5819.495
# ...                   ...         ...                 ...        ...
# 121440            Vietnam  98168829.0             308.127   6171.884
# 121644  Wallis and Futuna     11094.0                 NaN        NaN
# 122831              Yemen  30490639.0              53.508   1479.147
# 123408             Zambia  18920657.0              22.995   3689.251
# 123983           Zimbabwe  15092171.0              42.729   1899.775
#
#         Extreme Poverty  Human Development Index
# 599                 NaN                    0.511
# 1809                1.1                    0.795
# 2408                0.5                    0.748
# 3001                NaN                    0.868
# 3576                NaN                    0.581
# ...                 ...                      ...
# 121440              2.0                    0.704
# 121644              NaN                      NaN
# 122831             18.8                    0.470
# 123408             57.5                    0.584
# 123983             21.4                    0.571
#
# [218 rows x 6 columns]

# %%
countries_financial_df[~countries_financial_df.GDP.isna()]
# Out:
#                    Location  Population  Population Density        GDP  \
# 599             Afghanistan  39835428.0              54.422   1803.987
# 1809                Albania   2872934.0             104.871  11803.431
# 2408                Algeria  44616626.0              17.348  13913.839
# 3576                 Angola  33933611.0              23.890   5819.495
# 4412    Antigua and Barbuda     98728.0             231.845  21490.943
# ...                     ...         ...                 ...        ...
# 120808            Venezuela  28704947.0              36.253  16745.022
# 121440              Vietnam  98168829.0             308.127   6171.884
# 122831                Yemen  30490639.0              53.508   1479.147
# 123408               Zambia  18920657.0              22.995   3689.251
# 123983             Zimbabwe  15092171.0              42.729   1899.775
#
#         Extreme Poverty  Human Development Index
# 599                 NaN                    0.511
# 1809                1.1                    0.795
# 2408                0.5                    0.748
# 3576                NaN                    0.581
# 4412                NaN                    0.778
# ...                 ...                      ...
# 120808              NaN                    0.711
# 121440              2.0                    0.704
# 122831             18.8                    0.470
# 123408             57.5                    0.584
# 123983             21.4                    0.571
#
# [189 rows x 6 columns]

# %%
countries_financial_df = countries_financial_df[countries_financial_df.GDP.notna()]

# %%
countries_data
# Out:
#                  Location Collection Date  Total Vaccinations  \
# 543           Afghanistan      2021-08-20           1201286.0
# 1807              Albania      2021-10-13           1816580.0
# 2388              Algeria      2021-09-25          14082920.0
# 2982              Andorra      2021-09-26            102032.0
# 3575               Angola      2021-10-14           4448653.0
# ...                   ...             ...                 ...
# 121439            Vietnam      2021-10-14          59003239.0
# 121644  Wallis and Futuna      2021-10-12             11009.0
# 122813              Yemen      2021-09-27            356173.0
# 123370             Zambia      2021-09-07            602996.0
# 123982           Zimbabwe      2021-10-14           5654267.0
#
#         People Vaccinated  People Fully Vaccinated  Population  \
# 543              770542.0                 430744.0  39835428.0
# 1807             970703.0                 845877.0   2872934.0
# 2388            6017036.0                4032942.0  44616626.0
# 2982              54312.0                  47720.0     77354.0
# 3575            3158501.0                1290152.0  33933611.0
# ...                   ...                      ...         ...
# 121439         41811429.0               17191810.0  98168829.0
# 121644             5749.0                   5260.0     11094.0
# 122813           308025.0                  48148.0  30490639.0
# 123370           311049.0                 291947.0  18920657.0
# 123982          3200122.0                2454145.0  15092171.0
#
#         Percentage Fully Vaccinated
# 543                        1.081309
# 1807                      29.442967
# 2388                       9.039101
# 2982                      61.690410
# 3575                       3.801989
# ...                             ...
# 121439                    17.512494
# 121644                    47.413016
# 122813                     0.157911
# 123370                     1.543007
# 123982                    16.261047
#
# [217 rows x 7 columns]

# %%
countries_with_valid_gdp = countries_financial_df['Location'].to_list()
access_vaccine_data = countries_data[countries_data['Location'].isin(countries_with_valid_gdp)]
access_vaccine_data
# Out:
#                    Location Collection Date  Total Vaccinations  \
# 543             Afghanistan      2021-08-20           1201286.0
# 1807                Albania      2021-10-13           1816580.0
# 2388                Algeria      2021-09-25          14082920.0
# 3575                 Angola      2021-10-14           4448653.0
# 4410    Antigua and Barbuda      2021-10-13             99846.0
# ...                     ...             ...                 ...
# 120801            Venezuela      2021-10-08          16127242.0
# 121439              Vietnam      2021-10-14          59003239.0
# 122813                Yemen      2021-09-27            356173.0
# 123370               Zambia      2021-09-07            602996.0
# 123982             Zimbabwe      2021-10-14           5654267.0
#
#         People Vaccinated  People Fully Vaccinated  Population  \
# 543              770542.0                 430744.0  39835428.0
# 1807             970703.0                 845877.0   2872934.0
# 2388            6017036.0                4032942.0  44616626.0
# 3575            3158501.0                1290152.0  33933611.0
# 4410              54758.0                  45088.0     98728.0
# ...                   ...                      ...         ...
# 120801          9926613.0                6190629.0  28704947.0
# 121439         41811429.0               17191810.0  98168829.0
# 122813           308025.0                  48148.0  30490639.0
# 123370           311049.0                 291947.0  18920657.0
# 123982          3200122.0                2454145.0  15092171.0
#
#         Percentage Fully Vaccinated
# 543                        1.081309
# 1807                      29.442967
# 2388                       9.039101
# 3575                       3.801989
# 4410                      45.668909
# ...                             ...
# 120801                    21.566418
# 121439                    17.512494
# 122813                     0.157911
# 123370                     1.543007
# 123982                    16.261047
#
# [189 rows x 7 columns]

# %%
countries_vaccines_financial_data = pd.merge(access_vaccine_data, countries_financial_df, on='Location', how='outer')
countries_vaccines_financial_data.drop(columns=['Population_y'], inplace=True)
countries_vaccines_financial_data.rename(columns={'Population_x':'Population'}, inplace=True)

# %%
countries_vaccines_financial_data[countries_vaccines_financial_data['Location'] == 'Belgium']
# Out:
#    Location Collection Date  Total Vaccinations  People Vaccinated  \
# 16  Belgium      2021-10-14          16741664.0          8645665.0
#
#     People Fully Vaccinated  Population  Percentage Fully Vaccinated  \
# 16                8489064.0  11632334.0                    72.978166
#
#     Population Density        GDP  Extreme Poverty  Human Development Index
# 16             375.564  42658.576              0.2                    0.931

# %%
countries_vaccines_financial_data['GDP'].unique()
# Out:
# array([  1803.987,  11803.431,  13913.839,   5819.495,  21490.943,
#         18933.907,   8787.58 ,  35973.781,  44648.71 ,  45436.686,
#         15847.419,  27717.847,  43290.705,   3523.984,  16978.068,
#         17167.967,  42658.576,   7824.362,   2064.236,  50669.315,
#          8708.597,   6885.829,  11713.895,  15807.374,  14103.452,
#         71809.251,  18563.307,   1703.102,   3645.07 ,   3364.926,
#         44017.591,   6222.554,  49903.029,    661.24 ,   1768.153,
#         22767.037,  15308.712,  13254.949,   1413.89 ,   4881.406,
#         15524.995,   3601.006,  22669.797,  32415.132,  32605.906,
#           808.133,  46682.515,   2705.406,   9673.367,  14600.861,
#         10581.936,  10550.206,   7292.458,  22604.873,  29481.252,
#          7738.975,   1729.927,   8702.975,  40585.721,  38605.671,
#         16562.413,   1561.767,   9745.079,  45229.245,   4227.63 ,
#         24574.382,  13593.877,   7423.808,   1998.926,   1548.675,
#          7435.047,   1653.173,   4541.795,  56054.92 ,  26777.561,
#         46482.958,   6426.674,  11188.744,  19082.62 ,  15663.986,
#         67335.293,  33132.32 ,  35220.084,   8193.571,  39002.223,
#          8337.49 ,  24055.588,   2993.028,   1981.132,   9795.834,
#         65530.537,   3393.474,   6397.36 ,  25063.846,  13367.565,
#          2851.153,    752.788,  17881.509,  29524.265,  94277.965,
#        104861.851,   1416.44 ,   1095.042,  26808.164,  15183.616,
#          2014.306,  36513.323,   3597.633,  20292.745,  17336.469,
#          5189.972,  11840.846,  16409.288,   7485.013,   1136.103,
#          5591.597,   9541.808,  12895.635,   2442.804,  48472.545,
#         36085.843,   5321.444,    926.   ,   5338.454,  13111.214,
#         64800.057,  37960.709,   5034.708,   4449.898,  22267.037,
#          3823.194,   8827.01 ,  12236.706,   7599.188,  27216.445,
#         27936.896, 116935.6  ,  23313.199,  24765.954,   1854.211,
#         24654.385,  12951.839,  10727.146,   6021.557,  56861.47 ,
#          3052.714,  49045.411,   2470.58 ,  14048.881,  26382.287,
#          1390.3  ,  85535.383,  36327.232,  30155.152,  31400.84 ,
#          2205.923,  12294.876,  35938.374,   1569.888,  34272.36 ,
#         11669.077,   4466.507,  13767.119,  46949.283,  57410.166,
#          2896.913,   2683.304,  16277.671,   6570.102,   1429.813,
#          5425.621,  28763.071,  10849.297,  25129.341,  16389.023,
#          3575.104,   1697.707,   7894.393,  67293.483,  39753.244,
#         54225.446,  20551.409,   6253.104,   2921.909,  16745.022,
#          6171.884,   1479.147,   3689.251,   1899.775])

# %% [markdown]
# ### Countries GNI Classification
#  Classification is done based on the defined criteria by World Bank as seen here - https://datahelpdesk.worldbank.org/knowledgebase/articles/906519

# %%
gni_data = pd.read_csv('gni_per_capita.csv', skiprows=3, usecols=['Country Name', '2018', '2019', '2020'])
gni_data
# Out:
#                     Country Name          2018          2019          2020
# 0                          Aruba           NaN           NaN           NaN
# 1    Africa Eastern and Southern   3540.132713   3589.956043   3454.236460
# 2                    Afghanistan   2100.000000   2190.000000   2110.000000
# 3     Africa Western and Central   4040.129229   4167.624990   4066.878688
# 4                         Angola   6550.000000   6370.000000   6020.000000
# ..                           ...           ...           ...           ...
# 261                       Kosovo  11340.000000  12240.000000  11650.000000
# 262                  Yemen, Rep.           NaN           NaN           NaN
# 263                 South Africa  12520.000000  12640.000000  11870.000000
# 264                       Zambia   3550.000000   3560.000000   3360.000000
# 265                     Zimbabwe   3370.000000   3100.000000   2850.000000
#
# [266 rows x 4 columns]

# %%
gni_data.columns = ['Location', '2018', '2019', '2020']
gni_data
# Out:
#                         Location          2018          2019          2020
# 0                          Aruba           NaN           NaN           NaN
# 1    Africa Eastern and Southern   3540.132713   3589.956043   3454.236460
# 2                    Afghanistan   2100.000000   2190.000000   2110.000000
# 3     Africa Western and Central   4040.129229   4167.624990   4066.878688
# 4                         Angola   6550.000000   6370.000000   6020.000000
# ..                           ...           ...           ...           ...
# 261                       Kosovo  11340.000000  12240.000000  11650.000000
# 262                  Yemen, Rep.           NaN           NaN           NaN
# 263                 South Africa  12520.000000  12640.000000  11870.000000
# 264                       Zambia   3550.000000   3560.000000   3360.000000
# 265                     Zimbabwe   3370.000000   3100.000000   2850.000000
#
# [266 rows x 4 columns]

# %%
gni_data[['2018', '2019', '2020']]
# Out:
#              2018          2019          2020
# 0             NaN           NaN           NaN
# 1     3540.132713   3589.956043   3454.236460
# 2     2100.000000   2190.000000   2110.000000
# 3     4040.129229   4167.624990   4066.878688
# 4     6550.000000   6370.000000   6020.000000
# ..            ...           ...           ...
# 261  11340.000000  12240.000000  11650.000000
# 262           NaN           NaN           NaN
# 263  12520.000000  12640.000000  11870.000000
# 264   3550.000000   3560.000000   3360.000000
# 265   3370.000000   3100.000000   2850.000000
#
# [266 rows x 3 columns]

# %%
gni_df = gni_data[['2018', '2019', '2020']].copy()
gni_df
# Out:
#              2018          2019          2020
# 0             NaN           NaN           NaN
# 1     3540.132713   3589.956043   3454.236460
# 2     2100.000000   2190.000000   2110.000000
# 3     4040.129229   4167.624990   4066.878688
# 4     6550.000000   6370.000000   6020.000000
# ..            ...           ...           ...
# 261  11340.000000  12240.000000  11650.000000
# 262           NaN           NaN           NaN
# 263  12520.000000  12640.000000  11870.000000
# 264   3550.000000   3560.000000   3360.000000
# 265   3370.000000   3100.000000   2850.000000
#
# [266 rows x 3 columns]

# %%
gni_df.dtypes.to_dict()
# Out:
# {'2018': dtype('float64'), '2019': dtype('float64'), '2020': dtype('float64')}

# %%
gni_df.isnull().sum()
# Out:
# 2018    26
# 2019    28
# 2020    73
# dtype: int64

# %%
gni_df
# Out:
#              2018          2019          2020
# 0             NaN           NaN           NaN
# 1     3540.132713   3589.956043   3454.236460
# 2     2100.000000   2190.000000   2110.000000
# 3     4040.129229   4167.624990   4066.878688
# 4     6550.000000   6370.000000   6020.000000
# ..            ...           ...           ...
# 261  11340.000000  12240.000000  11650.000000
# 262           NaN           NaN           NaN
# 263  12520.000000  12640.000000  11870.000000
# 264   3550.000000   3560.000000   3360.000000
# 265   3370.000000   3100.000000   2850.000000
#
# [266 rows x 3 columns]

# %%
gni_df.dropna(how='all', inplace=True)

# %%
gni_df
# Out:
#              2018          2019          2020
# 1     3540.132713   3589.956043   3454.236460
# 2     2100.000000   2190.000000   2110.000000
# 3     4040.129229   4167.624990   4066.878688
# 4     6550.000000   6370.000000   6020.000000
# 5    13530.000000  14040.000000  13580.000000
# ..            ...           ...           ...
# 260   6230.000000   6480.000000           NaN
# 261  11340.000000  12240.000000  11650.000000
# 263  12520.000000  12640.000000  11870.000000
# 264   3550.000000   3560.000000   3360.000000
# 265   3370.000000   3100.000000   2850.000000
#
# [240 rows x 3 columns]

# %%
gni_df.isnull().sum()
# Out:
# 2018     0
# 2019     2
# 2020    47
# dtype: int64

# %%
# gni_df.isnull().sum()
gni_df
# Out:
#              2018          2019          2020
# 1     3540.132713   3589.956043   3454.236460
# 2     2100.000000   2190.000000   2110.000000
# 3     4040.129229   4167.624990   4066.878688
# 4     6550.000000   6370.000000   6020.000000
# 5    13530.000000  14040.000000  13580.000000
# ..            ...           ...           ...
# 260   6230.000000   6480.000000           NaN
# 261  11340.000000  12240.000000  11650.000000
# 263  12520.000000  12640.000000  11870.000000
# 264   3550.000000   3560.000000   3360.000000
# 265   3370.000000   3100.000000   2850.000000
#
# [240 rows x 3 columns]

# %%
gni_df['2020'].fillna(gni_df['2019'], inplace=True)

# %%
gni_df['2020'].fillna(gni_df['2018'], inplace=True)

# %%
gni_df
# Out:
#              2018          2019          2020
# 1     3540.132713   3589.956043   3454.236460
# 2     2100.000000   2190.000000   2110.000000
# 3     4040.129229   4167.624990   4066.878688
# 4     6550.000000   6370.000000   6020.000000
# 5    13530.000000  14040.000000  13580.000000
# ..            ...           ...           ...
# 260   6230.000000   6480.000000   6480.000000
# 261  11340.000000  12240.000000  11650.000000
# 263  12520.000000  12640.000000  11870.000000
# 264   3550.000000   3560.000000   3360.000000
# 265   3370.000000   3100.000000   2850.000000
#
# [240 rows x 3 columns]

# %%
gni_location = gni_data['Location']
gni_location
# Out:
# 0                            Aruba
# 1      Africa Eastern and Southern
# 2                      Afghanistan
# 3       Africa Western and Central
# 4                           Angola
#                   ...
# 261                         Kosovo
# 262                    Yemen, Rep.
# 263                   South Africa
# 264                         Zambia
# 265                       Zimbabwe
# Name: Location, Length: 266, dtype: object

# %%
gni = gni_df.join(gni_location)
gni
# Out:
#              2018          2019          2020                     Location
# 1     3540.132713   3589.956043   3454.236460  Africa Eastern and Southern
# 2     2100.000000   2190.000000   2110.000000                  Afghanistan
# 3     4040.129229   4167.624990   4066.878688   Africa Western and Central
# 4     6550.000000   6370.000000   6020.000000                       Angola
# 5    13530.000000  14040.000000  13580.000000                      Albania
# ..            ...           ...           ...                          ...
# 260   6230.000000   6480.000000   6480.000000                        Samoa
# 261  11340.000000  12240.000000  11650.000000                       Kosovo
# 263  12520.000000  12640.000000  11870.000000                 South Africa
# 264   3550.000000   3560.000000   3360.000000                       Zambia
# 265   3370.000000   3100.000000   2850.000000                     Zimbabwe
#
# [240 rows x 4 columns]

# %%
gni.isnull().sum()
# Out:
# 2018        0
# 2019        2
# 2020        0
# Location    0
# dtype: int64

# %%
gni = gni[gni['Location'].isin(countries)]
gni
# Out:
#         2018     2019     2020              Location
# 2     2100.0   2190.0   2110.0           Afghanistan
# 4     6550.0   6370.0   6020.0                Angola
# 5    13530.0  14040.0  13580.0               Albania
# 8    68810.0  70300.0  70300.0  United Arab Emirates
# 9    22470.0  22080.0  20210.0             Argentina
# ..       ...      ...      ...                   ...
# 260   6230.0   6480.0   6480.0                 Samoa
# 261  11340.0  12240.0  11650.0                Kosovo
# 263  12520.0  12640.0  11870.0          South Africa
# 264   3550.0   3560.0   3360.0                Zambia
# 265   3370.0   3100.0   2850.0              Zimbabwe
#
# [166 rows x 4 columns]

# %%
gni[['Location', '2018', '2019', '2020']]
# Out:
#                  Location     2018     2019     2020
# 2             Afghanistan   2100.0   2190.0   2110.0
# 4                  Angola   6550.0   6370.0   6020.0
# 5                 Albania  13530.0  14040.0  13580.0
# 8    United Arab Emirates  68810.0  70300.0  70300.0
# 9               Argentina  22470.0  22080.0  20210.0
# ..                    ...      ...      ...      ...
# 260                 Samoa   6230.0   6480.0   6480.0
# 261                Kosovo  11340.0  12240.0  11650.0
# 263          South Africa  12520.0  12640.0  11870.0
# 264                Zambia   3550.0   3560.0   3360.0
# 265              Zimbabwe   3370.0   3100.0   2850.0
#
# [166 rows x 4 columns]

# %%
gni_2020 = gni[['Location', '2020']]
gni_2020.columns = ['Location', 'GNI']
gni_2020
# Out:
#                  Location      GNI
# 2             Afghanistan   2110.0
# 4                  Angola   6020.0
# 5                 Albania  13580.0
# 8    United Arab Emirates  70300.0
# 9               Argentina  20210.0
# ..                    ...      ...
# 260                 Samoa   6480.0
# 261                Kosovo  11650.0
# 263          South Africa  11870.0
# 264                Zambia   3360.0
# 265              Zimbabwe   2850.0
#
# [166 rows x 2 columns]

# %%
gni_2020[gni_2020['Location'] == 'Curacao']
# Out:
#    Location      GNI
# 51  Curacao  26620.0

# %%
vax_gni = pd.merge(countries_vaccines_financial_data, gni_2020, on='Location', how='inner')
# vax_gni = countries_vaccines_financial_data.join(gni_2020)

# %%
vax_gni
# Out:
#                 Location Collection Date  Total Vaccinations  \
# 0            Afghanistan      2021-08-20           1201286.0
# 1                Albania      2021-10-13           1816580.0
# 2                Algeria      2021-09-25          14082920.0
# 3                 Angola      2021-10-14           4448653.0
# 4    Antigua and Barbuda      2021-10-13             99846.0
# ..                   ...             ...                 ...
# 158           Uzbekistan      2021-10-07          21978290.0
# 159              Vanuatu      2021-10-12             87583.0
# 160              Vietnam      2021-10-14          59003239.0
# 161               Zambia      2021-09-07            602996.0
# 162             Zimbabwe      2021-10-14           5654267.0
#
#      People Vaccinated  People Fully Vaccinated  Population  \
# 0             770542.0                 430744.0  39835428.0
# 1             970703.0                 845877.0   2872934.0
# 2            6017036.0                4032942.0  44616626.0
# 3            3158501.0                1290152.0  33933611.0
# 4              54758.0                  45088.0     98728.0
# ..                 ...                      ...         ...
# 158         12025985.0                4941860.0  33935765.0
# 159            59215.0                  28368.0    314464.0
# 160         41811429.0               17191810.0  98168829.0
# 161           311049.0                 291947.0  18920657.0
# 162          3200122.0                2454145.0  15092171.0
#
#      Percentage Fully Vaccinated  Population Density        GDP  \
# 0                       1.081309              54.422   1803.987
# 1                      29.442967             104.871  11803.431
# 2                       9.039101              17.348  13913.839
# 3                       3.801989              23.890   5819.495
# 4                      45.668909             231.845  21490.943
# ..                           ...                 ...        ...
# 158                    14.562395              76.134   6253.104
# 159                     9.021064              22.662   2921.909
# 160                    17.512494             308.127   6171.884
# 161                     1.543007              22.995   3689.251
# 162                    16.261047              42.729   1899.775
#
#      Extreme Poverty  Human Development Index      GNI
# 0                NaN                    0.511   2110.0
# 1                1.1                    0.795  13580.0
# 2                0.5                    0.748  11010.0
# 3                NaN                    0.581   6020.0
# 4                NaN                    0.778  18610.0
# ..               ...                      ...      ...
# 158              NaN                    0.720   7350.0
# 159             13.2                    0.609   2880.0
# 160              2.0                    0.704   8200.0
# 161             57.5                    0.584   3360.0
# 162             21.4                    0.571   2850.0
#
# [163 rows x 12 columns]

# %% [markdown]
# Country Income Classification
#
# The classification is based on the World bank's income threshold classification for 2020
#
# | Class              |  Income Level            |
# |--------------------|--------------------------|
# | Low income         |	< 1,036                 |
# |Lower-middle income | 1,035 – 4,045            |
# |Upper-middle income | 4,046 - 12,535           |
# |High income         | > 12,535                 |

# %%
def add_income_class(row):
    if row['GNI'] < 1036:
        val = 'Low Income'
    elif row['GNI'] > 1036 and row['GNI'] <= 4045:
        val = 'Lower-Middle Income'
    elif row['GNI'] > 4045 and row['GNI'] <= 12535:
        val = 'Upper-Middle Income'
    elif row['GNI'] > 12535:
        val = 'High Income'
    return val

# %%
vax_gni['Income Class'] = vax_gni.apply(add_income_class, axis=1)

# %%
vax_gni
# Out:
#                 Location Collection Date  Total Vaccinations  \
# 0            Afghanistan      2021-08-20           1201286.0
# 1                Albania      2021-10-13           1816580.0
# 2                Algeria      2021-09-25          14082920.0
# 3                 Angola      2021-10-14           4448653.0
# 4    Antigua and Barbuda      2021-10-13             99846.0
# ..                   ...             ...                 ...
# 158           Uzbekistan      2021-10-07          21978290.0
# 159              Vanuatu      2021-10-12             87583.0
# 160              Vietnam      2021-10-14          59003239.0
# 161               Zambia      2021-09-07            602996.0
# 162             Zimbabwe      2021-10-14           5654267.0
#
#      People Vaccinated  People Fully Vaccinated  Population  \
# 0             770542.0                 430744.0  39835428.0
# 1             970703.0                 845877.0   2872934.0
# 2            6017036.0                4032942.0  44616626.0
# 3            3158501.0                1290152.0  33933611.0
# 4              54758.0                  45088.0     98728.0
# ..                 ...                      ...         ...
# 158         12025985.0                4941860.0  33935765.0
# 159            59215.0                  28368.0    314464.0
# 160         41811429.0               17191810.0  98168829.0
# 161           311049.0                 291947.0  18920657.0
# 162          3200122.0                2454145.0  15092171.0
#
#      Percentage Fully Vaccinated  Population Density        GDP  \
# 0                       1.081309              54.422   1803.987
# 1                      29.442967             104.871  11803.431
# 2                       9.039101              17.348  13913.839
# 3                       3.801989              23.890   5819.495
# 4                      45.668909             231.845  21490.943
# ..                           ...                 ...        ...
# 158                    14.562395              76.134   6253.104
# 159                     9.021064              22.662   2921.909
# 160                    17.512494             308.127   6171.884
# 161                     1.543007              22.995   3689.251
# 162                    16.261047              42.729   1899.775
#
#      Extreme Poverty  Human Development Index      GNI         Income Class
# 0                NaN                    0.511   2110.0  Lower-Middle Income
# 1                1.1                    0.795  13580.0          High Income
# 2                0.5                    0.748  11010.0  Upper-Middle Income
# 3                NaN                    0.581   6020.0  Upper-Middle Income
# 4                NaN                    0.778  18610.0          High Income
# ..               ...                      ...      ...                  ...
# 158              NaN                    0.720   7350.0  Upper-Middle Income
# 159             13.2                    0.609   2880.0  Lower-Middle Income
# 160              2.0                    0.704   8200.0  Upper-Middle Income
# 161             57.5                    0.584   3360.0  Lower-Middle Income
# 162             21.4                    0.571   2850.0  Lower-Middle Income
#
# [163 rows x 13 columns]

# %%
vax_gni.dtypes.to_dict()
# Out:
# {'Location': dtype('O'),
#  'Collection Date': dtype('O'),
#  'Total Vaccinations': dtype('float64'),
#  'People Vaccinated': dtype('float64'),
#  'People Fully Vaccinated': dtype('float64'),
#  'Population': dtype('float64'),
#  'Percentage Fully Vaccinated': dtype('float64'),
#  'Population Density': dtype('float64'),
#  'GDP': dtype('float64'),
#  'Extreme Poverty': dtype('float64'),
#  'Human Development Index': dtype('float64'),
#  'GNI': dtype('float64'),
#  'Income Class': dtype('O')}

# %%
alt.Chart(vax_gni).mark_circle().encode(
    alt.X('GNI', scale=alt.Scale(zero=False)),
    alt.Y('Percentage Fully Vaccinated', scale=alt.Scale(zero=False, padding=1)),
    alt.Color('Income Class', sort=['High Income', 'Upper-Middle Income', 'Lower-Middle Income']),
    size='Human Development Index',
    tooltip=['Location', 'GNI', 'Income Class', 'Total Vaccinations', 'Percentage Fully Vaccinated']
).interactive().properties(height=400, width=700, title='A graph of Percentage of Fully Vaccinated vs Gross National Income grouped by Income Classes')
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Insights on Percentage Vaccinated vs Population size
# The graph of Percentage Vaccinated vs Population shows that the Percentage of vaccinated is almost independent of the population size but instead more dependent on the country's access to vaccine. This is seen from the outliers (China & India) with very close population size 1444216102 and 1393409033 respectively, but have a wider gap in there vaccinated percentages with China 70.78% and India 19.93%

# %%
alt.Chart(vax_gni).mark_circle().encode(
    alt.X('Population', scale=alt.Scale(zero=False)),
    alt.Y('Percentage Fully Vaccinated', scale=alt.Scale(zero=False, padding=1)),
    alt.Color('Income Class', sort=['High Income', 'Upper-Middle Income', 'Lower-Middle Income']),
    size='Human Development Index',
    tooltip=['Location', 'GNI', 'Income Class', 'Percentage Fully Vaccinated', 'Population']
).interactive().properties(height=400, width=700, title='A graph of Percentage of Fully Vaccinated vs Country Population')
# Out:
# alt.Chart(...)

# %%
from vega_datasets import data
source = data.iris()
source
# Out:
#      sepalLength  sepalWidth  petalLength  petalWidth    species
# 0            5.1         3.5          1.4         0.2     setosa
# 1            4.9         3.0          1.4         0.2     setosa
# 2            4.7         3.2          1.3         0.2     setosa
# 3            4.6         3.1          1.5         0.2     setosa
# 4            5.0         3.6          1.4         0.2     setosa
# ..           ...         ...          ...         ...        ...
# 145          6.7         3.0          5.2         2.3  virginica
# 146          6.3         2.5          5.0         1.9  virginica
# 147          6.5         3.0          5.2         2.0  virginica
# 148          6.2         3.4          5.4         2.3  virginica
# 149          5.9         3.0          5.1         1.8  virginica
#
# [150 rows x 5 columns]

# %%
source.dtypes.to_dict()
# Out:
# {'sepalLength': dtype('float64'),
#  'sepalWidth': dtype('float64'),
#  'petalLength': dtype('float64'),
#  'petalWidth': dtype('float64'),
#  'species': dtype('O')}

# %%
alt.Chart(source).mark_circle().encode(
    alt.X('sepalLength', scale=alt.Scale(zero=False)),
    alt.Y('sepalWidth', scale=alt.Scale(zero=False, padding=1)),
    color='species',
    size='petalWidth'
)
# Out:
# alt.Chart(...)
